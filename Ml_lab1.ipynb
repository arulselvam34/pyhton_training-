# %% [markdown]
# <a href="https://colab.research.google.com/github/arulselvam34/pyhton_training-/blob/main/Ml_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
x = sm.add_constant(x)
model = sm.OLS(y,x)
results = model.fit()
print(results.summary())
y_pred = results.predict(x)
plt.scatter(x[:,1],y,color = 'blue',label = 'Data Points')
plt.plot(x[:,1],y_pred,color = 'red',label = 'Regression Line')
plt.xlabel('Independent Variable(X)')
plt.ylabel('Dependent Variable(Y)')
plt.title('Simple Linear Regression')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py:531: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   res = hypotest_fun_out(*samples, **kwds)
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.575
# Model:                            OLS   Adj. R-squared:                  0.537
# Method:                 Least Squares   F-statistic:                     14.91
# Date:                Thu, 22 Aug 2024   Prob (F-statistic):            0.00265
# Time:                        06:06:29   Log-Likelihood:                -41.809
# No. Observations:                  13   AIC:                             87.62
# Df Residuals:                      11   BIC:                             88.75
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...
